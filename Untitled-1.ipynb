# %%
print("Hello, World!")
# Out:
# Hello, World!

# %%
True
# Out:
# True

# %%
False
# Out:
# False

# %%
type(True), type(False)
# Out:
# (bool, bool)

# %%
5 > 7
# Out:
# False

# %%
type(5 > 7)
# Out:
# bool
